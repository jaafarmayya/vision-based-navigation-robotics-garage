# %%
import cv2
import numpy as np
import time
import serial
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from PIL import Image

physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)

model = load_model('224_224_augmented.h5', compile=False)

    
@tf.function(experimental_relax_shapes=True)
def predict_class(img):
    img = tf.image.resize(img, [224, 224])
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.expand_dims(img, axis=0)
    img = tf.keras.applications.mobilenet.preprocess_input(img)
    predictions = model(img)
    return tf.argmax(predictions[0])



# Set up the serial connection
ser = serial.Serial('COM7', 115200, timeout=0.1)  # Change 'COM3' to the appropriate port

time.sleep(2)  # Wait for the connection to be established

def send_data(data):
    ser.write((data + '\n').encode())  # Send data to Arduino with newline character
    print(f"Sent: {data}")

def receive_data():
    while True:
        data = ser.readline().decode().strip()  # Read data from Arduino
        if data:
            print(f"Received: {data}")
            return data
        time.sleep(0.01)  # Short delay to prevent CPU overuse

# PID Controller class
class PID:
    def __init__(self, Kp, Ki, Kd):
        self.Kp = Kp
        self.Ki = Ki
        self.Kd = Kd
        self.previous_error = 0
        self.integral = 0

    def compute(self, error, delta_time):
        self.integral += error * delta_time
        derivative = (error - self.previous_error) / delta_time
        output = self.Kp * error + self.Ki * self.integral + self.Kd * derivative
        self.previous_error = error
        return output

def process_image(img):
    # Resize the image to 640x480
    resized_img = cv2.resize(img, (640, 480))

    # Rotate the image 90 degrees clockwise
    rotated_img = cv2.rotate(resized_img, cv2.ROTATE_90_CLOCKWISE)

    # Crop the image height to take the upper half
    height, width = rotated_img.shape[:2]
    cropped_img = rotated_img[:height-285, :2*188]

    return cropped_img

# Initialize PID controller
pid = PID(Kp=0.15, Ki=0, Kd=0)

lower1 = np.array([10, 43, 0])
upper1 = np.array([38, 255, 255])
lower_red = np.array([170, 0, 0])
upper_red = np.array([179, 255, 255])

red_threshold = 286 #samsung
x0 = 10
y0 = 5

IP = "https://192.168.43.1:8080/video"
cap = cv2.VideoCapture(IP)
previous_time = time.time()
slot = int(input("Enter the Parking Slot Number"))
index = 100
while True:
    _, img = cap.read()
    if img is None:
        break
    # Resize the image
    resized_img = process_image(img)  # Resize to 640x480 or any desired size
    img_height, img_width = resized_img.shape[:2]

    image = cv2.cvtColor(resized_img, cv2.COLOR_BGR2HSV)
    mask1 = cv2.inRange(image, lower1, upper1)
    mask_red = cv2.inRange(image, lower_red, upper_red)
    
    contours1, _ = cv2.findContours(mask1, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    contours_red, _ = cv2.findContours(mask_red, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    if contours1:
        # List to hold contours and their centroids
        contours_with_centroids = []

        for contour in contours1:
            if cv2.contourArea(contour) > 100:
                m = cv2.moments(contour)
                if m["m00"] != 0:
                    cx = int(m["m10"] / m["m00"])
                    cy = int(m["m01"] / m["m00"])
                    contours_with_centroids.append((contour, (cx, cy)))
        
        # Find the contour with the largest cy value
        if contours_with_centroids:
            largest_contour, (cx, cy) = max(contours_with_centroids, key=lambda x: x[1][1])

            x, y, w, h = cv2.boundingRect(largest_contour)
            cv2.rectangle(resized_img, (x, y), (x + w, y + h), (0, 255, 0), 2)
            
            # Optionally, draw the centroid
            cv2.circle(resized_img, (cx, cy), 5, (255, 0, 0), -1)
            
            # Calculate the error
            error = cx - (img_width // 2)
            current_time = time.time()
            delta_time = current_time - previous_time
            previous_time = current_time

            # Compute the PID output
            pid_output = pid.compute(error, delta_time)
            # send_data(str(round(pid_output)));
            # Receive data from Arduino
            #response = receive_data()
        if contours_red:
        # List to hold contours and their centroids
          red_contours_with_centroids = []
  
          for contour in contours_red:
              if cv2.contourArea(contour) > 100:
                  m = cv2.moments(contour)
                  if m["m00"] != 0:
                      cx = int(m["m10"] / m["m00"])
                      cy = int(m["m01"] / m["m00"])

                      red_contours_with_centroids.append((contour, (cx, cy)))
          
          # Find the contour with the largest cy value
          if red_contours_with_centroids:
              largest_contour, (cx, cy) = max(red_contours_with_centroids, key=lambda x: x[1][1])
              
              x, y, w, h = cv2.boundingRect(largest_contour)
              x1 = x- x0
              y1 = y-y0
              x2 = x + w+x0
              y2 = y + h+y0

              cv2.rectangle(resized_img, (x1, y1), (x2, y2), (0, 0, 255), 2)
              cv2.circle(resized_img, (cx, cy), 5, (255, 0, 0), -1)

              sample = resized_img[y1:y2,x1:x2]
              
              index = predict_class(sample)
              print("Index of the maximum value:", index)
              if(cy>=red_threshold):
                  if(index == slot):
                      send_data("s")
                      print("Reached")
             
            
           # print(f"Area: {cv2.contourArea(largest_contour)}, Centroid: ({cx}, {cy}), Error: {error}, PID Output: {pid_output}")
    # Display the resized image with the highlighted contour
    cv2.imshow("Result", resized_img)
    # cv2.imshow("Red", sample)
    if cv2.waitKey(5) == 27:
        send_data("s");
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2 
import numpy as np
import time

def nothing(x):
    pass
IP = "https://192.168.43.1:8080/video"
cap = cv2.VideoCapture(IP)
# cap = cv2.VideoCapture("python/yellow.mp4")
cv2.namedWindow("Trackbars")

cv2.createTrackbar("L - H", "Trackbars", 0, 179, nothing)
cv2.createTrackbar("L - S", "Trackbars", 0, 255, nothing)
cv2.createTrackbar("L - V", "Trackbars", 0, 255, nothing)
cv2.createTrackbar("U - H", "Trackbars", 179, 179, nothing)
cv2.createTrackbar("U - S", "Trackbars", 255, 255, nothing)
cv2.createTrackbar("U - V", "Trackbars", 255, 255, nothing)
# _,frame1 = cap.read()
while True:
    _,frame = cap.read()
    #_,frame = cap.read()
    # frame = frame1
    frame = cv2.GaussianBlur(frame, (11, 11), 0)

    time.sleep(0.1)
    width = 640
    height = 480
    frame = cv2.resize(frame, (width, height))
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    l_h = cv2.getTrackbarPos("L - H", "Trackbars")
    l_s = cv2.getTrackbarPos("L - S", "Trackbars")
    l_v = cv2.getTrackbarPos("L - V", "Trackbars")
    u_h = cv2.getTrackbarPos("U - H", "Trackbars")
    u_s = cv2.getTrackbarPos("U - S", "Trackbars")
    u_v = cv2.getTrackbarPos("U - V", "Trackbars")
    
    lower_blue = np.array([l_h, l_s, l_v])
    upper_blue = np.array([u_h, u_s, u_v])
    mask = cv2.inRange(hsv, lower_blue, upper_blue)
    
    result = cv2.bitwise_and(frame, frame, mask=mask)
    
    cv2.imshow("frame", frame)
    cv2.imshow("mask", mask)
    cv2.imshow("result", result)

    key = cv2.waitKey(1)
    if key == 27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
import tensorflow as tf
import cv2
import numpy as np
import serial
import time

@tf.function(experimental_relax_shapes=True)
def predict_class(img):
    img = tf.image.resize(img, [224, 224])
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.expand_dims(img, axis=0)
    img = tf.keras.applications.mobilenet.preprocess_input(img)
    predictions = model(img)
    return tf.argmax(predictions[0])

# Set up the serial connection
# ser = serial.Serial('COM7', 115200, timeout=0.1)  # Change 'COM3' to the appropriate port

time.sleep(2)  # Wait for the connection to be established

# def send_data(data):
#     ser.write((data + '\n').encode())  # Send data to Arduino with newline character
#     print(f"Sent: {data}")

# def receive_data():
#     while True:
#         data = ser.readline().decode().strip()  # Read data from Arduino
#         if data:
#             print(f"Received: {data}")
#             return data
#         time.sleep(0.01)  # Short delay to prevent CPU overuse

# PID Controller class
class PID:
    def __init__(self, Kp, Ki, Kd):
        self.Kp = Kp
        self.Ki = Ki
        self.Kd = Kd
        self.kp_back = Kp
        self.previous_error = 0
        self.integral = 0

    def compute(self, error, delta_time):
        self.Kp = self.kp_back
        if abs(error) > 100: 
            print('Kp changed')
            self.Kp = 1
            send_data("t")
        self.integral += error * delta_time
        derivative = (error - self.previous_error) / delta_time
        output = self.Kp * error + self.Ki * self.integral + self.Kd * derivative
        self.previous_error = error
        return output

def process_image(img):
    # Resize the image to 640x480
    resized_img = cv2.resize(img, (640, 480))

    # Rotate the image 90 degrees clockwise
    rotated_img = cv2.rotate(resized_img, cv2.ROTATE_90_CLOCKWISE)

    # Crop the image height to take the upper half
    height, width = rotated_img.shape[:2]
    cropped_img = rotated_img[:height-285, :2*188]

    return cropped_img

# Initialize PID controller
pid = PID(Kp=0.15, Ki=0, Kd=0)

lower1 = np.array([10, 43, 0])
upper1 = np.array([38, 255, 255])
lower_red_1 = np.array([170, 50, 0])
upper_red_1 = np.array([179, 255, 255])
lower_red_2 = np.array([0, 50, 0])
upper_red_2 = np.array([10, 255, 255])

red_threshold = 286  # samsung
x0 = 10
y0 = 5

IP = "https://192.168.43.1:8080/video"
cap = cv2.VideoCapture(IP)
previous_time = time.time()
# slot = int(input("Enter the Parking Slot Number"))

   
# Below VideoWriter object will create 
# a frame of above defined The output  
# is stored in 'filename.avi' file. 


while True:
    ret, img = cap.read()
    out.write(img)
    if not ret:
        print("Failed to capture image from camera")
        break
    
    # Resize the image
    resized_img = process_image(img)  # Resize to 640x480 or any desired size
    img_height, img_width = resized_img.shape[:2]

    image = cv2.cvtColor(resized_img, cv2.COLOR_BGR2HSV)
    mask1 = cv2.inRange(image, lower1, upper1)
    mask_red_1 = cv2.inRange(image, lower_red_1, upper_red_1)
    mask_red_2 = cv2.inRange(image, lower_red_2, upper_red_2)
    mask_red = mask_red_1 + mask_red_2
    contours1, _ = cv2.findContours(mask1, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    contours_red, _ = cv2.findContours(mask_red, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    
    if contours1:
        # List to hold contours and their centroids
        contours_with_centroids = []

        for contour in contours1:
            if cv2.contourArea(contour) > 100:
                m = cv2.moments(contour)
                if m["m00"] != 0:
                    cx = int(m["m10"] / m["m00"])
                    cy = int(m["m01"] / m["m00"])
                    contours_with_centroids.append((contour, (cx, cy)))
        
        # Find the contour with the largest cy value
        if contours_with_centroids:
            largest_contour, (cx, cy) = max(contours_with_centroids, key=lambda x: x[1][1])

            x, y, w, h = cv2.boundingRect(largest_contour)
            cv2.rectangle(resized_img, (x, y), (x + w, y + h), (0, 255, 0), 2)
            
            # Optionally, draw the centroid
            cv2.circle(resized_img, (cx, cy), 5, (255, 0, 0), -1)
            
            # Calculate the error
            error = cx - (img_width // 2)
            current_time = time.time()
            delta_time = current_time - previous_time
            previous_time = current_time

            # Compute the PID output
            pid_output = pid.compute(error, delta_time)
            # send_data(str(round(pid_output)))
            # Receive data from Arduino
            # response = receive_data()
    
    if contours_red:
        # List to hold contours and their centroids
        red_contours_with_centroids = []

        for contour in contours_red:
            if cv2.contourArea(contour) > 300:
                m = cv2.moments(contour)
                if m["m00"] != 0:
                    cx = int(m["m10"] / m["m00"])
                    cy = int(m["m01"] / m["m00"])

                    red_contours_with_centroids.append((contour, (cx, cy)))
        
        # Find the contour with the largest cy value
        if red_contours_with_centroids:
            largest_contour, (cx, cy) = max(red_contours_with_centroids, key=lambda x: x[1][1])
            
            x, y, w, h = cv2.boundingRect(largest_contour)
            x1 = x - x0
            y1 = y - y0
            x2 = x + w + x0
            y2 = y + h + y0

            cv2.rectangle(resized_img, (x1, y1), (x2, y2), (0, 0, 255), 2)
            cv2.circle(resized_img, (cx, cy), 5, (255, 0, 0), -1)

            sample = resized_img[y1:y2, x1:x2]
            t1 = time.time()
            predicted_index = predict_class(sample)
            predicted_label = int(predicted_index.numpy())
            print("Index of the maximum value:", predicted_label)
            print("Time of prediction = " + str(time.time() - t1))
             # Put the predicted label above the red rectangle
            label_position = (x1, y1 - 10)  # Position for the label text
            cv2.putText(resized_img, "Predicted Label: "+ str(predicted_label), label_position, cv2.FONT_HERSHEY_SIMPLEX, 0.65, (0, 0, 255), 1)

            # if(cy >= red_threshold):
            #     if(index == slot):
            #         send_data("s")
            #         print("Reached")

    # Write the frame to the video file
    
    
    # Display the resized image with the highlighted contour
    cv2.imshow("Result", resized_img)
    # cv2.imshow("Red", sample)
    if cv2.waitKey(1) & 0xFF == ord('s'): 
            break
     
# send_data("s")
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Index of the maximum value: 1
# Time of prediction = 1.1516821384429932
# Index of the maximum value: 1
# Time of prediction = 0.6332244873046875
# Index of the maximum value: 1
# Time of prediction = 0.6108434200286865
# Index of the maximum value: 1
# Time of prediction = 0.09399914741516113
# Index of the maximum value: 1
# Time of prediction = 0.09299659729003906
# Index of the maximum value: 1
# Time of prediction = 0.062003135681152344
# Index of the maximum value: 1
# Time of prediction = 0.024028301239013672
# Index of the maximum value: 1
# Time of prediction = 0.024348020553588867
# Index of the maximum value: 1
# Time of prediction = 0.029028654098510742
# Index of the maximum value: 1
# Time of prediction = 0.02400064468383789
# Index of the maximum value: 1
# Time of prediction = 0.02399587631225586
# Index of the maximum value: 1
# Time of prediction = 0.024998903274536133
# Index of the maximum value: 1
# Time of prediction = 0.024001598358154297
# Index of the maximum value: 1
# Time of prediction = 0.0240018367767334
# Index of the maximum value: 1
# Time of prediction = 0.02199244499206543
# Index of the maximum value: 1
# Time of prediction = 0.023314476013183594
# Index of the maximum value: 1
# Time of prediction = 0.02503514289855957
# Index of the maximum value: 1
# Time of prediction = 0.023902416229248047
# Index of the maximum value: 1
# Time of prediction = 0.025032758712768555
# Index of the maximum value: 1
# Time of prediction = 0.023999452590942383
# Index of the maximum value: 1
# Time of prediction = 0.023368120193481445
# Index of the maximum value: 1
# Time of prediction = 0.02271270751953125
# Index of the maximum value: 1
# Time of prediction = 0.02366781234741211
# Index of the maximum value: 1
# Time of prediction = 0.02999138832092285
# Index of the maximum value: 1
# Time of prediction = 0.023997068405151367
# Index of the maximum value: 1
# Time of prediction = 0.022998332977294922
# Index of the maximum value: 1
# Time of prediction = 0.023403167724609375
# Index of the maximum value: 1
# Time of prediction = 0.02299785614013672
# Index of the maximum value: 1
# Time of prediction = 0.02523016929626465
# Index of the maximum value: 1
# Time of prediction = 0.0240020751953125
# Index of the maximum value: 1
# Time of prediction = 0.023000240325927734
# Index of the maximum value: 1
# Time of prediction = 0.022998809814453125
# Index of the maximum value: 1
# Time of prediction = 0.02599811553955078
# Index of the maximum value: 1
# Time of prediction = 0.026996374130249023
# Index of the maximum value: 1
# Time of prediction = 0.022647619247436523
# Index of the maximum value: 1
# Time of prediction = 0.02499842643737793
# Index of the maximum value: 1
# Time of prediction = 0.02199840545654297
# Index of the maximum value: 1
# Time of prediction = 0.02299976348876953
# Index of the maximum value: 1
# Time of prediction = 0.023997783660888672
# Index of the maximum value: 1
# Time of prediction = 0.023128032684326172
# Index of the maximum value: 1
# Time of prediction = 0.025009870529174805
# Index of the maximum value: 1
# Time of prediction = 0.022962093353271484
# Index of the maximum value: 1
# Time of prediction = 0.023000001907348633
# Index of the maximum value: 1
# Time of prediction = 0.024997472763061523
# Index of the maximum value: 1
# Time of prediction = 0.022998809814453125
# Index of the maximum value: 1
# Time of prediction = 0.02299809455871582
# Index of the maximum value: 1
# Time of prediction = 0.02359151840209961
# Index of the maximum value: 1
# Time of prediction = 0.02302861213684082
# Index of the maximum value: 1
# Time of prediction = 0.023993253707885742
# Index of the maximum value: 1
# Time of prediction = 0.024054288864135742
# Index of the maximum value: 1
# Time of prediction = 0.023784637451171875
# Index of the maximum value: 1
# Time of prediction = 0.02370285987854004
# Index of the maximum value: 1
# Time of prediction = 0.023680448532104492
# Index of the maximum value: 1
# Time of prediction = 0.025368690490722656
# Index of the maximum value: 1
# Time of prediction = 0.03799557685852051
# Index of the maximum value: 1
# Time of prediction = 0.024000167846679688
# Index of the maximum value: 1
# Time of prediction = 0.02400064468383789
# Index of the maximum value: 1
# Time of prediction = 0.023000240325927734
# Index of the maximum value: 1
# Time of prediction = 0.025998353958129883
# Index of the maximum value: 1
# Time of prediction = 0.02299785614013672
# Index of the maximum value: 1
# Time of prediction = 0.022998332977294922
# Index of the maximum value: 1
# Time of prediction = 0.027998685836791992
# Index of the maximum value: 1
# Time of prediction = 0.03000164031982422
# Index of the maximum value: 1
# Time of prediction = 0.027995824813842773
# Index of the maximum value: 1
# Time of prediction = 0.027121782302856445
# Index of the maximum value: 1
# Time of prediction = 0.03030681610107422
# Index of the maximum value: 1
# Time of prediction = 0.027005910873413086
# Index of the maximum value: 1
# Time of prediction = 0.029999732971191406
# Index of the maximum value: 1
# Time of prediction = 0.02799820899963379
# Index of the maximum value: 1
# Time of prediction = 0.026999711990356445
# Index of the maximum value: 1
# Time of prediction = 0.02706456184387207
# Index of the maximum value: 1
# Time of prediction = 0.027772903442382812
# Index of the maximum value: 1
# Time of prediction = 0.03000044822692871
# Index of the maximum value: 1
# Time of prediction = 0.02899456024169922
# Index of the maximum value: 1
# Time of prediction = 0.029993772506713867
# Index of the maximum value: 1
# Time of prediction = 0.027001142501831055
# Index of the maximum value: 1
# Time of prediction = 0.027001380920410156
# Index of the maximum value: 1
# Time of prediction = 0.026998281478881836
# Index of the maximum value: 1
# Time of prediction = 0.027997255325317383
# Index of the maximum value: 1
# Time of prediction = 0.030040264129638672
# Index of the maximum value: 1
# Time of prediction = 0.02741384506225586
# Index of the maximum value: 1
# Time of prediction = 0.028997182846069336
# Index of the maximum value: 1
# Time of prediction = 0.03099966049194336
# Index of the maximum value: 1
# Time of prediction = 0.02797102928161621
# Index of the maximum value: 1
# Time of prediction = 0.02700209617614746
# Index of the maximum value: 1
# Time of prediction = 0.0299990177154541
# Index of the maximum value: 1
# Time of prediction = 0.029025793075561523
# Index of the maximum value: 1
# Time of prediction = 0.028000831604003906
# Index of the maximum value: 1
# Time of prediction = 0.026996135711669922
# Index of the maximum value: 1
# Time of prediction = 0.026996135711669922
# Index of the maximum value: 1
# Time of prediction = 0.027490854263305664
# Index of the maximum value: 1
# Time of prediction = 0.028471946716308594
# Index of the maximum value: 1
# Time of prediction = 0.02723526954650879
# Index of the maximum value: 1
# Time of prediction = 0.028733491897583008
# Index of the maximum value: 1
# Time of prediction = 0.026997804641723633
# Index of the maximum value: 1
# Time of prediction = 0.04100298881530762
# Index of the maximum value: 1
# Time of prediction = 0.03400230407714844
# Index of the maximum value: 1
# Time of prediction = 0.025971651077270508
# Index of the maximum value: 1
# Time of prediction = 0.031007766723632812
# Index of the maximum value: 1
# Time of prediction = 0.03598737716674805
# Index of the maximum value: 1
# Time of prediction = 0.02703118324279785
# Index of the maximum value: 1
# Time of prediction = 0.028058290481567383
# Index of the maximum value: 1
# Time of prediction = 0.027994394302368164
# Index of the maximum value: 1
# Time of prediction = 0.027986764907836914
# Index of the maximum value: 1
# Time of prediction = 0.04100513458251953
# Index of the maximum value: 1
# Time of prediction = 0.02797675132751465
# Index of the maximum value: 1
# Time of prediction = 0.027868270874023438
# Index of the maximum value: 1
# Time of prediction = 0.026998281478881836
# Index of the maximum value: 1
# Time of prediction = 0.02902531623840332
# Index of the maximum value: 1
# Time of prediction = 0.0289764404296875
# Index of the maximum value: 1
# Time of prediction = 0.02699732780456543
# Index of the maximum value: 1
# Time of prediction = 0.0280001163482666
# Index of the maximum value: 1
# Time of prediction = 0.026994943618774414
# Index of the maximum value: 1
# Time of prediction = 0.02899932861328125
# Index of the maximum value: 1
# Time of prediction = 0.02803349494934082
# Index of the maximum value: 1
# Time of prediction = 0.026964902877807617
# Index of the maximum value: 1
# Time of prediction = 0.02699899673461914
# Index of the maximum value: 1
# Time of prediction = 0.026999950408935547
# Index of the maximum value: 1
# Time of prediction = 0.02699756622314453
# Index of the maximum value: 1
# Time of prediction = 0.028029680252075195
# Index of the maximum value: 1
# Time of prediction = 0.027996063232421875
# Index of the maximum value: 1
# Time of prediction = 0.02799534797668457
# Index of the maximum value: 1
# Time of prediction = 0.02700209617614746
# Index of the maximum value: 1
# Time of prediction = 0.030028581619262695
# Index of the maximum value: 1
# Time of prediction = 0.027003049850463867
# Index of the maximum value: 1
# Time of prediction = 0.0270233154296875
# Index of the maximum value: 1
# Time of prediction = 0.028998851776123047
# Index of the maximum value: 1
# Time of prediction = 0.028000831604003906
# Index of the maximum value: 1
# Time of prediction = 0.027996301651000977
# Index of the maximum value: 1
# Time of prediction = 0.0339963436126709
# Index of the maximum value: 1
# Time of prediction = 0.03299832344055176
# Index of the maximum value: 1
# Time of prediction = 0.031996965408325195
# Index of the maximum value: 1
# Time of prediction = 0.030997514724731445
# Index of the maximum value: 1
# Time of prediction = 0.02899932861328125
# Index of the maximum value: 1
# Time of prediction = 0.030996322631835938
# Index of the maximum value: 1
# Time of prediction = 0.02999734878540039
# Index of the maximum value: 1
# Time of prediction = 0.027997255325317383
# Index of the maximum value: 1
# Time of prediction = 0.026999235153198242
# Index of the maximum value: 1
# Time of prediction = 0.029999256134033203
# Index of the maximum value: 1
# Time of prediction = 0.02599644660949707
# Index of the maximum value: 1
# Time of prediction = 0.028998136520385742
# Index of the maximum value: 1
# Time of prediction = 0.028997182846069336
# Index of the maximum value: 1
# Time of prediction = 0.03000187873840332
# Index of the maximum value: 1
# Time of prediction = 0.031996965408325195
# Index of the maximum value: 1
# Time of prediction = 0.02800154685974121
# Index of the maximum value: 1
# Time of prediction = 0.02799701690673828
# Index of the maximum value: 1
# Time of prediction = 0.026999711990356445
# Index of the maximum value: 1
# Time of prediction = 0.029000282287597656
# Index of the maximum value: 1
# Time of prediction = 0.03300213813781738
# Index of the maximum value: 1
# Time of prediction = 0.029001235961914062
# Index of the maximum value: 1
# Time of prediction = 0.026996374130249023
# Index of the maximum value: 1
# Time of prediction = 0.027400493621826172
# Index of the maximum value: 1
# Time of prediction = 0.029001712799072266
# Index of the maximum value: 1
# Time of prediction = 0.02797389030456543
# Index of the maximum value: 1
# Time of prediction = 0.028002023696899414
# Index of the maximum value: 1
# Time of prediction = 0.02699565887451172
# Index of the maximum value: 1
# Time of prediction = 0.028998851776123047
# Index of the maximum value: 1
# Time of prediction = 0.02700018882751465
# Index of the maximum value: 1
# Time of prediction = 0.060007572174072266
# Index of the maximum value: 1
# Time of prediction = 0.050563812255859375
# Index of the maximum value: 1
# Time of prediction = 0.03600168228149414
# Index of the maximum value: 1
# Time of prediction = 0.03099989891052246
# Index of the maximum value: 1
# Time of prediction = 0.028999805450439453
# Index of the maximum value: 1
# Time of prediction = 0.02700066566467285
# Index of the maximum value: 1
# Time of prediction = 0.029000520706176758
# Index of the maximum value: 1
# Time of prediction = 0.027999401092529297
# Index of the maximum value: 1
# Time of prediction = 0.027993202209472656
# Index of the maximum value: 1
# Time of prediction = 0.02697610855102539
# Index of the maximum value: 1
# Time of prediction = 0.03899574279785156
# Index of the maximum value: 1
# Time of prediction = 0.04500102996826172
# Index of the maximum value: 1
# Time of prediction = 0.027999401092529297
# Index of the maximum value: 1
# Time of prediction = 0.029998302459716797
# Index of the maximum value: 1
# Time of prediction = 0.03199911117553711
# Index of the maximum value: 1
# Time of prediction = 0.03201103210449219
# Index of the maximum value: 1
# Time of prediction = 0.03699994087219238
# Index of the maximum value: 1
# Time of prediction = 0.028996944427490234
# Index of the maximum value: 1
# Time of prediction = 0.035066843032836914
# Index of the maximum value: 1
# Time of prediction = 0.04199790954589844
# Index of the maximum value: 1
# Time of prediction = 0.03287100791931152
# Index of the maximum value: 1
# Time of prediction = 0.037058353424072266
# Index of the maximum value: 1
# Time of prediction = 0.030998706817626953
# Index of the maximum value: 1
# Time of prediction = 0.03198957443237305
# Index of the maximum value: 1
# Time of prediction = 0.03003215789794922
# Index of the maximum value: 1
# Time of prediction = 0.030979156494140625
# Index of the maximum value: 1
# Time of prediction = 0.03698253631591797
# Index of the maximum value: 1
# Time of prediction = 0.029999971389770508
# Index of the maximum value: 1
# Time of prediction = 0.03365325927734375
# Index of the maximum value: 1
# Time of prediction = 0.027994871139526367
# Index of the maximum value: 1
# Time of prediction = 0.036002159118652344
# Index of the maximum value: 1
# Time of prediction = 0.027001380920410156
# Index of the maximum value: 1
# Time of prediction = 0.03099822998046875
# Index of the maximum value: 1
# Time of prediction = 0.03199911117553711
# Index of the maximum value: 1
# Time of prediction = 0.02898883819580078
# Index of the maximum value: 1
# Time of prediction = 0.0300445556640625
# Index of the maximum value: 1
# Time of prediction = 0.028995037078857422
# Index of the maximum value: 1
# Time of prediction = 0.03246903419494629
# Index of the maximum value: 1
# Time of prediction = 0.03607940673828125
# Index of the maximum value: 1
# Time of prediction = 0.03399801254272461
# Index of the maximum value: 1
# Time of prediction = 0.03000020980834961
# Index of the maximum value: 1
# Time of prediction = 0.03099799156188965
# Index of the maximum value: 1
# Time of prediction = 0.04099106788635254
# Index of the maximum value: 1
# Time of prediction = 0.03496742248535156
# Index of the maximum value: 1
# Time of prediction = 0.03299999237060547
# Index of the maximum value: 1
# Time of prediction = 0.030109643936157227
# Index of the maximum value: 1
# Time of prediction = 0.03699541091918945
# Index of the maximum value: 1
# Time of prediction = 0.028001070022583008
# Index of the maximum value: 1
# Time of prediction = 0.0279998779296875
# Index of the maximum value: 1
# Time of prediction = 0.027024030685424805
# Index of the maximum value: 1
# Time of prediction = 0.02899646759033203
# Index of the maximum value: 1
# Time of prediction = 0.039003610610961914
# Index of the maximum value: 1
# Time of prediction = 0.03000187873840332
# Index of the maximum value: 1
# Time of prediction = 0.027998685836791992
# Index of the maximum value: 1
# Time of prediction = 0.02799677848815918
# Index of the maximum value: 1
# Time of prediction = 0.028441429138183594
# Index of the maximum value: 1
# Time of prediction = 0.030997753143310547
# Index of the maximum value: 1
# Time of prediction = 0.027025938034057617
# Index of the maximum value: 1
# Time of prediction = 0.030066251754760742
# Index of the maximum value: 1
# Time of prediction = 0.026996374130249023
# Index of the maximum value: 1
# Time of prediction = 0.028018951416015625
# Index of the maximum value: 1
# Time of prediction = 0.030989408493041992
# Index of the maximum value: 1
# Time of prediction = 0.04699873924255371
# Index of the maximum value: 1
# Time of prediction = 0.029994726181030273
# Index of the maximum value: 1
# Time of prediction = 0.028996706008911133
# Index of the maximum value: 1
# Time of prediction = 0.032073020935058594
# Index of the maximum value: 1
# Time of prediction = 0.02999734878540039
# Index of the maximum value: 1
# Time of prediction = 0.02599620819091797
# Index of the maximum value: 1
# Time of prediction = 0.02799820899963379
# Index of the maximum value: 1
# Time of prediction = 0.035497426986694336
# Index of the maximum value: 1
# Time of prediction = 0.03900027275085449
# Index of the maximum value: 1
# Time of prediction = 0.0319974422454834
# Index of the maximum value: 1
# Time of prediction = 0.030001163482666016
# Index of the maximum value: 1
# Time of prediction = 0.028493165969848633
# Index of the maximum value: 1
# Time of prediction = 0.0339961051940918
# Index of the maximum value: 1
# Time of prediction = 0.03000164031982422
# Index of the maximum value: 1
# Time of prediction = 0.028002262115478516
# Index of the maximum value: 1
# Time of prediction = 0.029997587203979492
# Index of the maximum value: 1
# Time of prediction = 0.031998634338378906
# Index of the maximum value: 1
# Time of prediction = 0.029999971389770508
# Index of the maximum value: 1
# Time of prediction = 0.03499007225036621
# Index of the maximum value: 1
# Time of prediction = 0.03960871696472168
# Index of the maximum value: 1
# Time of prediction = 0.030998706817626953
# Index of the maximum value: 1
# Time of prediction = 0.03199958801269531
# Index of the maximum value: 1
# Time of prediction = 0.0339961051940918
# Index of the maximum value: 1
# Time of prediction = 0.049996376037597656
# Index of the maximum value: 1
# Time of prediction = 0.035993099212646484
# Index of the maximum value: 1
# Time of prediction = 0.029033422470092773
# Index of the maximum value: 1
# Time of prediction = 0.030997514724731445
# Index of the maximum value: 1
# Time of prediction = 0.038376808166503906
# Index of the maximum value: 1
# Time of prediction = 0.03399777412414551
# Index of the maximum value: 1
# Time of prediction = 0.02900075912475586
# Index of the maximum value: 1
# Time of prediction = 0.03899860382080078
# Index of the maximum value: 1
# Time of prediction = 0.03599977493286133
# Index of the maximum value: 1
# Time of prediction = 0.032010555267333984
# Index of the maximum value: 1
# Time of prediction = 0.029999494552612305
# Index of the maximum value: 1
# Time of prediction = 0.033016204833984375
# Index of the maximum value: 1
# Time of prediction = 0.03499627113342285
# Index of the maximum value: 1
# Time of prediction = 0.032000064849853516
# Index of the maximum value: 1
# Time of prediction = 0.03099966049194336
# Index of the maximum value: 1
# Time of prediction = 0.030993938446044922
# Index of the maximum value: 1
# Time of prediction = 0.030995607376098633
# Index of the maximum value: 1
# Time of prediction = 0.031998395919799805
# Index of the maximum value: 1
# Time of prediction = 0.027999162673950195
# Index of the maximum value: 1
# Time of prediction = 0.1219482421875
# Index of the maximum value: 1
# Time of prediction = 0.09799647331237793
# Index of the maximum value: 1
# Time of prediction = 0.11300039291381836
# Index of the maximum value: 1
# Time of prediction = 0.09734869003295898
# Index of the maximum value: 1
# Time of prediction = 0.09430289268493652
# Index of the maximum value: 1
# Time of prediction = 0.026994705200195312
# Index of the maximum value: 1
# Time of prediction = 0.02700042724609375
# Index of the maximum value: 1
# Time of prediction = 0.03199887275695801
# Index of the maximum value: 1
# Time of prediction = 0.027001142501831055
# Index of the maximum value: 1
# Time of prediction = 0.023996591567993164
# Index of the maximum value: 1
# Time of prediction = 0.024007558822631836
# Index of the maximum value: 1
# Time of prediction = 0.026987791061401367
# Index of the maximum value: 1
# Time of prediction = 0.025002241134643555
# Index of the maximum value: 1
# Time of prediction = 0.024004697799682617
# Index of the maximum value: 1
# Time of prediction = 0.024997949600219727
# Index of the maximum value: 1
# Time of prediction = 0.022994041442871094
# Index of the maximum value: 1
# Time of prediction = 0.031998634338378906
# Index of the maximum value: 1
# Time of prediction = 0.02799677848815918
# Index of the maximum value: 1
# Time of prediction = 0.023999929428100586
# Index of the maximum value: 1
# Time of prediction = 0.023998737335205078
# Index of the maximum value: 1
# Time of prediction = 0.02399754524230957
# Index of the maximum value: 1
# Time of prediction = 0.023995637893676758
# Index of the maximum value: 1
# Time of prediction = 0.029586076736450195
# Index of the maximum value: 1
# Time of prediction = 0.02400970458984375
# Index of the maximum value: 1
# Time of prediction = 0.022998571395874023
# Index of the maximum value: 1
# Time of prediction = 0.025999069213867188
# Index of the maximum value: 1
# Time of prediction = 0.029016971588134766
# Index of the maximum value: 1
# Time of prediction = 0.024968862533569336
# Index of the maximum value: 1
# Time of prediction = 0.025998830795288086
# Index of the maximum value: 2
# Time of prediction = 0.023002147674560547
# Index of the maximum value: 2
# Time of prediction = 0.02399921417236328
# Index of the maximum value: 2
# Time of prediction = 0.02599644660949707
# Index of the maximum value: 2
# Time of prediction = 0.023029088973999023
# Index of the maximum value: 2
# Time of prediction = 0.025999784469604492
# Index of the maximum value: 2
# Time of prediction = 0.03151297569274902
# Index of the maximum value: 2
# Time of prediction = 0.026005029678344727
# Index of the maximum value: 2
# Time of prediction = 0.025996923446655273
# Index of the maximum value: 2
# Time of prediction = 0.025998353958129883
# Index of the maximum value: 2
# Time of prediction = 0.024047374725341797
# Index of the maximum value: 2
# Time of prediction = 0.02500152587890625
# Index of the maximum value: 2
# Time of prediction = 0.022998571395874023
# Index of the maximum value: 2
# Time of prediction = 0.03200221061706543
# Index of the maximum value: 2
# Time of prediction = 0.02399468421936035
# Index of the maximum value: 2
# Time of prediction = 0.027999162673950195
# Index of the maximum value: 2
# Time of prediction = 0.023999452590942383
# Index of the maximum value: 2
# Time of prediction = 0.026964902877807617
# Index of the maximum value: 2
# Time of prediction = 0.025003910064697266
# Index of the maximum value: 2
# Time of prediction = 0.024967670440673828
# Index of the maximum value: 2
# Time of prediction = 0.024996042251586914
# Index of the maximum value: 2
# Time of prediction = 0.021996021270751953
# Index of the maximum value: 2
# Time of prediction = 0.023995399475097656
# Index of the maximum value: 2
# Time of prediction = 0.03099989891052246
# Index of the maximum value: 2
# Time of prediction = 0.023998260498046875
# Index of the maximum value: 2
# Time of prediction = 0.026027202606201172
# Index of the maximum value: 2
# Time of prediction = 0.025998830795288086
# Index of the maximum value: 2
# Time of prediction = 0.024996280670166016
# Index of the maximum value: 2
# Time of prediction = 0.026999473571777344
# Index of the maximum value: 2
# Time of prediction = 0.022998809814453125
# Index of the maximum value: 2
# Time of prediction = 0.022998571395874023
# Index of the maximum value: 2
# Time of prediction = 0.03499746322631836
# Index of the maximum value: 2
# Time of prediction = 0.026003599166870117
# Index of the maximum value: 2
# Time of prediction = 0.028999805450439453
# Index of the maximum value: 2
# Time of prediction = 0.02499985694885254
# Index of the maximum value: 2
# Time of prediction = 0.02899909019470215
# Index of the maximum value: 2
# Time of prediction = 0.02300119400024414
# Index of the maximum value: 2
# Time of prediction = 0.02601337432861328
# Index of the maximum value: 2
# Time of prediction = 0.03600335121154785
# Index of the maximum value: 2
# Time of prediction = 0.023998498916625977
# Index of the maximum value: 2
# Time of prediction = 0.02599954605102539
# Index of the maximum value: 2
# Time of prediction = 0.024000167846679688
# Index of the maximum value: 2
# Time of prediction = 0.024004697799682617
# Index of the maximum value: 2
# Time of prediction = 0.025006532669067383
# Index of the maximum value: 2
# Time of prediction = 0.02300095558166504
# Index of the maximum value: 2
# Time of prediction = 0.026999950408935547
# Index of the maximum value: 2
# Time of prediction = 0.022999048233032227
# Index of the maximum value: 2
# Time of prediction = 0.03399944305419922
# Index of the maximum value: 2
# Time of prediction = 0.02299642562866211
# Index of the maximum value: 2
# Time of prediction = 0.02600264549255371
# Index of the maximum value: 2
# Time of prediction = 0.025995492935180664
# Index of the maximum value: 2
# Time of prediction = 0.023969411849975586
# Index of the maximum value: 2
# Time of prediction = 0.02899909019470215
# Index of the maximum value: 2
# Time of prediction = 0.023000478744506836
# Index of the maximum value: 2
# Time of prediction = 0.02300739288330078
# Index of the maximum value: 2
# Time of prediction = 0.02402520179748535
# Index of the maximum value: 2
# Time of prediction = 0.0340118408203125
# Index of the maximum value: 2
# Time of prediction = 0.02699899673461914
# Index of the maximum value: 2
# Time of prediction = 0.024001359939575195
# Index of the maximum value: 2
# Time of prediction = 0.024002552032470703
# Index of the maximum value: 2
# Time of prediction = 0.023237943649291992
# Index of the maximum value: 2
# Time of prediction = 0.024007081985473633
# Index of the maximum value: 2
# Time of prediction = 0.024026870727539062
# Index of the maximum value: 2
# Time of prediction = 0.028998851776123047
# Index of the maximum value: 2
# Time of prediction = 0.025998353958129883
# Index of the maximum value: 2
# Time of prediction = 0.025031328201293945
# Index of the maximum value: 2
# Time of prediction = 0.02600240707397461
# Index of the maximum value: 2
# Time of prediction = 0.024000883102416992
# Index of the maximum value: 2
# Time of prediction = 0.028000593185424805
# Index of the maximum value: 2
# Time of prediction = 0.02599787712097168
# Index of the maximum value: 2
# Time of prediction = 0.0279996395111084
# Index of the maximum value: 2
# Time of prediction = 0.025035381317138672
# Index of the maximum value: 2
# Time of prediction = 0.026994943618774414
# Index of the maximum value: 2
# Time of prediction = 0.02400064468383789
# Index of the maximum value: 2
# Time of prediction = 0.025995969772338867
# Index of the maximum value: 2
# Time of prediction = 0.027999162673950195
# Index of the maximum value: 6
# Time of prediction = 0.027997255325317383
# Index of the maximum value: 6
# Time of prediction = 0.030994653701782227
# Index of the maximum value: 6
# Time of prediction = 0.023997783660888672
# Index of the maximum value: 6
# Time of prediction = 0.0259859561920166
# Index of the maximum value: 6
# Time of prediction = 0.02602529525756836
# Index of the maximum value: 6
# Time of prediction = 0.03299427032470703
# Index of the maximum value: 2
# Time of prediction = 0.021998882293701172
# Index of the maximum value: 2
# Time of prediction = 0.023998260498046875
# Index of the maximum value: 2
# Time of prediction = 0.024959564208984375
# Index of the maximum value: 2
# Time of prediction = 0.027001619338989258
# Index of the maximum value: 2
# Time of prediction = 0.0319972038269043
# Index of the maximum value: 2
# Time of prediction = 0.022539854049682617
# Index of the maximum value: 0
# Time of prediction = 0.029006004333496094
# Index of the maximum value: 1
# Time of prediction = 0.024001359939575195
# Kp changed
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# Cell In[103], line 141
#     138         previous_time = current_time
#     140         # Compute the PID output
# --> 141         pid_output = pid.compute(error, delta_time)
#     142         # send_data(str(round(pid_output)))
#     143         # Receive data from Arduino
#     144         # response = receive_data()
#     146 if contours_red:
#     147     # List to hold contours and their centroids
#
# Cell In[103], line 48, in PID.compute(self, error, delta_time)
#      46     print('Kp changed')
#      47     self.Kp = 1
# ---> 48     send_data("t")
#      49 self.integral += error * delta_time
#      50 derivative = (error - self.previous_error) / delta_time
#
# Cell In[88], line 22, in send_data(data)
#      21 def send_data(data):
# ---> 22     ser.write((data + '\n').encode())  # Send data to Arduino with newline character
#      23     print(f"Sent: {data}")
#
# File ~\anaconda3\envs\MobileNet\lib\site-packages\serial\serialwin32.py:317, in Serial.write(self, data)
#     315 if self._write_timeout != 0:  # if blocking (None) or w/ write timeout (>0)
#     316     if not success and win32.GetLastError() not in (win32.ERROR_SUCCESS, win32.ERROR_IO_PENDING):
# --> 317         raise SerialException("WriteFile failed ({!r})".format(ctypes.WinError()))
#     319     # Wait for the write to complete.
#     320     #~ win32.WaitForSingleObject(self._overlapped_write.hEvent, win32.INFINITE)
#     321     win32.GetOverlappedResult(self._port_handle, self._overlapped_write, ctypes.byref(n), True)
#
# SerialException: WriteFile failed (PermissionError(13, 'The device does not recognize the command.', None, 22))

# %%
# !pip install pyserial
# Out:
# The video was successfully saved
